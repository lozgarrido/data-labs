# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
beverages = pd.read_csv('../data/liquor_store_sales.csv')
beverages.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
sum_by_item = beverages.groupby("ItemType").sum()

#Clean dataframe and draw it
sum_by_item = sum_by_item[["RetailSales", "RetailTransfers", "WarehouseSales"]]
sum_by_item.plot(kind="bar");

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
top_suppliers = beverages.groupby("Supplier").sum()

#Create "TotalSales" column
top_suppliers["TotalSales"] = top_suppliers["RetailTransfers"] + top_suppliers["WarehouseSales"]

#Sort dataframe by 'TotalSales' and select top ten
top_suppliers = top_suppliers.sort_values("TotalSales", ascending=False)[:10]

#Clean dataframe and reindex to show biggest value on top
top_suppliers = top_suppliers[["RetailSales", "WarehouseSales"]]
top_suppliers = top_suppliers.iloc[::-1]

#Draw plot
top_suppliers.plot(kind="barh");

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
avg_sales = beverages.copy()

#Create new column from "Age" and "Month"
avg_sales["Month"] = avg_sales.Month.map("{:02}".format)
avg_sales["Date"] = (avg_sales["Year"].map(str) + avg_sales["Month"])

#Clean dataframe
avg_sales = avg_sales[["Date", "RetailSales", "RetailTransfers", "WarehouseSales"]]
avg_sales = avg_sales.groupby("Date").mean()

avg_sales.head()
# Out:
#         RetailSales  RetailTransfers  WarehouseSales
# Date
# 201704     0.000000        15.707503        0.000000
# 201705     7.038838         7.421817       27.310548
# 201706     7.143914         6.950396       27.839069
# 201708     6.409991         6.584726       28.122641
# 201709     6.757254         6.419721       22.817909

# %%
plt.figure(figsize=(20,5))
plt.grid(True)
plt.plot(avg_sales);

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
avg_sales.plot(kind="bar");

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
retail_sales = beverages.copy()

#Create new column from "Age" and "Month"
retail_sales["Month"] = retail_sales.Month.map("{:02}".format)
retail_sales["Date"] = (retail_sales["Year"].map(str) + retail_sales["Month"])

#Clean dataframe
retail_sales = retail_sales[["Date", "ItemType", "RetailSales"]]
retail_sales = retail_sales.set_index("Date")

#Create pivot table
retail_sales = pd.pivot_table(retail_sales, 
                           values = "RetailSales", 
                           index = ["Date", "ItemType"],
                           aggfunc = {"RetailSales" : sum})

retail_sales.head()
# Out:
#                      RetailSales
# Date   ItemType
# 201704 BEER                  0.0
#        LIQUOR                0.0
#        NON-ALCOHOL           0.0
#        REF                   0.0
#        STR_SUPPLIES          0.0

# %%
plt.figure(figsize=(20,5))
plt.grid(True)
plt.plot(retail_sales);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-67774b344eb5> in <module>
#       1 plt.figure(figsize=(20,5))
#       2 plt.grid(True)
# ----> 3 plt.plot(retail_sales);
#
# /usr/local/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     241     def _xy_from_xy(self, x, y):
#     242         if self.axes.xaxis is not None and self.axes.yaxis is not None:
# --> 243             bx = self.axes.xaxis.update_units(x)
#     244             by = self.axes.yaxis.update_units(y)
#     245
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in update_units(self, data)
#    1491         neednew = self.converter != converter
#    1492         self.converter = converter
# -> 1493         default = self.converter.default_units(data, self)
#    1494         if default is not None and self.units is None:
#    1495             self.set_units(default)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/category.py in default_units(data, axis)
#     113         # default_units->axis_info->convert
#     114         if axis.units is None:
# --> 115             axis.set_units(UnitData(data))
#     116         else:
#     117             axis.units.update(data)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/category.py in __init__(self, data)
#     179         self._counter = itertools.count()
#     180         if data is not None:
# --> 181             self.update(data)
#     182
#     183     @staticmethod
#
# /usr/local/lib/python3.7/site-packages/matplotlib/category.py in update(self, data)
#     216             # OrderedDict just iterates over unique values in data.
#     217             if not isinstance(val, (str, bytes)):
# --> 218                 raise TypeError("{val!r} is not a string".format(val=val))
#     219             if convertible:
#     220                 # this will only be called so long as convertible is True.
#
# TypeError: ('201704', 'BEER') is not a string

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*
